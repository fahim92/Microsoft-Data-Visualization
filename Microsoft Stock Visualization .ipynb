# %%
import pandas as pd

# %%
microsoft_data=pd.read_csv('MSFT.csv',index_col='Date')
microsoft_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-06-24  137.000000  138.399994  137.000000  137.779999  136.105179
# 2019-06-25  137.250000  137.589996  132.729996  133.429993  131.808044
# 2019-06-26  134.350006  135.740005  133.600006  133.929993  132.301971
# 2019-06-27  134.139999  134.710007  133.509995  134.149994  132.519287
# 2019-06-28  134.570007  134.600006  133.160004  133.960007  132.331619
# ...                ...         ...         ...         ...         ...
# 2020-06-18  194.000000  196.490005  194.000000  196.320007  196.320007
# 2020-06-19  198.589996  199.289993  194.369995  195.149994  195.149994
# 2020-06-22  195.789993  200.759995  195.229996  200.570007  200.570007
# 2020-06-23  202.089996  203.949997  201.429993  201.910004  201.910004
# 2020-06-24  201.604004  203.229996  196.750000  197.750000  197.750000
#
#               Volume
# Date
# 2019-06-24  20628800
# 2019-06-25  33327400
# 2019-06-26  23657700
# ...

# %%
microsoft_data['Open'].plot(legend=True)

# %%
microsoft_data['High'].plot(legend=True)

# %%
microsoft_data['Low'].plot(legend=True)

# %%
microsoft_data['Close'].plot(legend=True)

# %%
microsoft_data['Adj Close'].plot(legend=True)

# %%
microsoft_data['Volume'].plot(legend=True)

# %%
import matplotlib.pyplot as plt
microsoft_data['Open'].plot(color='r',style='.',legend=True)
microsoft_data['High'].plot(legend=True)
microsoft_data['Low'].plot(color='y',style='.-',legend=True)
microsoft_data['Close'].plot(color='b',style='-.',legend=True)
microsoft_data['Adj Close'].plot(style='+',legend=True)
plt.savefig('microsoft.jpg')
plt.show()
